# %%
pip install --user prince

# %%
import pandas as pd
import prince
import numpy

# %%
df = pd.read_csv('CSV/Terry_Stops.csv')

# %%
df = df[['Frisk Flag', 
             'Officer Race', 
             'Officer Gender', 
             'Subject Perceived Race', 
             'Subject Age Group', 
             'Subject Perceived Gender']].copy()

# %%
print("The original data set contains: {} rows and {} columns".format(df.shape[0], df.shape[1]))
print("Features of the original data set:\n", list(df.columns))
# Out:
# The original data set contains: 42566 rows and 7 columns
# Features of the original data set:
#  ['Frisk Flag', 'Officer Race', 'Officer Gender', 'Weapon Type', 'Subject Perceived Race', 'Subject Age Group', 'Subject Perceived Gender']

# %%
# number of categorical features
print("Number of categorical features : {}".format(len(df.select_dtypes(include=['object']).columns)))
print("Number of continuous features : {}".format(len(df.select_dtypes(include=['int64', 'float64']).columns)))
# Out:
# Number of categorical features : 7
# Number of continuous features : 0

# %%
df.nunique()
# Out:
# Frisk Flag                   3
# Officer Race                 9
# Officer Gender               3
# Weapon Type                 21
# Subject Perceived Race      10
# Subject Age Group            7
# Subject Perceived Gender     6
# dtype: int64

# %%
mca = prince.MCA(
        n_components=2,
        n_iter=3,
        copy=True,
        check_input=True,
        engine='auto',
        random_state=42
        )
df_mca = mca.fit(df)

ax = df_mca.plot_coordinates(
        X=df,
        ax=None,
        figsize=(8, 10),
        show_row_points=False,
        row_points_size=0,
        show_row_labels=False,
        show_column_points=True,
        column_points_size=30,
        show_column_labels=True,
        legend_n_cols=1
               ).legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
mca = prince.MCA()

# %%
mca = mca.fit(X)

# %%
mca = mca.transform(X)

# %%
print(mca)

# %%
ax = mca.plot_coordinates(
     X=X,
     ax=None,
     figsize=(6, 6),
     show_row_points=True,
     row_points_size=10,
     show_row_labels=False,
     show_column_points=True,
     column_points_size=30,
     show_column_labels=False,
     legend_n_cols=1
     )
